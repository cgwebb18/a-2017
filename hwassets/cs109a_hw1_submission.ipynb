# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get(" http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")
page = req.text
soup = BeautifulSoup(page, 'html.parser')

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %%
tables_wikitable = soup.find_all("table", "wikitable")
len(tables_wikitable)
# Out:
# 1

# %%
rows = [row for row in tables_wikitable[0].find_all("tr")]
header_row = rows[0]
header_row
columns = [col.get_text() for col in header_row.find_all("th") if col.get_text()]
columns
# Out:
# ['№', 'Title', 'Artist(s)']

# %%
values = []
for row in rows[1:]:
    count = 0
    d_1 = dict()
    for td in row.find_all("td"):
        count += 1
        text = td.get_text()
        if count == 1:
            rank = int(text)
            d_1['ranking'] = rank
        elif count == 2:
            song_url_list = []
            for link in td.find_all("a"):
                song_url_list.append(link.get("href"))
            if "/" in text:
                songs = text.split("/")
                d_1['title'] = songs
            else:
                d_1['title'] = text
            d_1['songurl'] = song_url_list
        elif count == 3:
            artist_url_list = []
            for link in td.find_all("a"):
                artist_url_list.append(link.get("href"))
            if "featuring" and "and" in text:
                text = "Kanye featuring TPain and Taylor Swift"
                text1 = text.split(" featuring ")
                #text1 = ["Kanye", "TPain and Taylor Swift"]
                text2 = text1[1].split(" and ")
                #text2 = ["TPain", "Taylor Swift"]
                text = text2.insert(0, text1[0])
            elif "featuring" in text:
                text = text.split(" featuring ")
            d_1['band_singer'] = text
            d_1['url'] = artist_url_list
            values.append(d_1)
            d_1 = dict()
values
# Out:
# [{'band_singer': 'Simon & Garfunkel',
#   'ranking': 1,
#   'songurl': ['/wiki/Bridge_over_Troubled_Water_(song)'],
#   'title': '"Bridge over Troubled Water"',
#   'url': ['/wiki/Simon_%26_Garfunkel']},
#  {'band_singer': 'The Carpenters',
#   'ranking': 2,
#   'songurl': ['/wiki/(They_Long_to_Be)_Close_to_You'],
#   'title': '"(They Long to Be) Close to You"',
#   'url': ['/wiki/The_Carpenters']},
#  {'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'songurl': ['/wiki/American_Woman'],
#   'title': '"American Woman"',
#   'url': ['/wiki/The_Guess_Who']},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'songurl': ['/wiki/Raindrops_Keep_Fallin%27_on_My_Head'],
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': ['/wiki/B.J._Thomas']},
#  {'band_singer': 'Edwin Starr',
#   'ranking': 5,
#   'songurl': ['/wiki/War_(The_Temptations_song)#Edwin_Starr_version'],
#   'title': '"War"',
#   'url': ['/wiki/Edwin_Starr']},
#  {'band_singer': 'Diana Ross',
#   'ranking': 6,
#   'songurl': ['/wiki/Ain%27t_No_Mountain_High_Enough'],
#   'title': '"Ain\'t No Mountain High Enough"',
#   'url': ['/wiki/Diana_Ross']},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 7,
#   'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)'],
#   'title': '"I\'ll Be There"',
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': 'Rare Earth',
#   'ranking': 8,
#   'songurl': ['/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version'],
#   'title': '"Get Ready"',
#   'url': ['/wiki/Rare_Earth_(band)']},
#  {'band_singer': 'The Beatles',
#   'ranking': 9,
#   'songurl': ['/wiki/Let_It_Be_(song)'],
#   'title': '"Let It Be"',
#   'url': ['/wiki/The_Beatles']},
#  {'band_singer': 'Freda Payne',
#   'ranking': 10,
#   'songurl': ['/wiki/Band_of_Gold_(Freda_Payne_song)'],
#   'title': '"Band of Gold"',
#   'url': ['/wiki/Freda_Payne']},
#  {'band_singer': 'Three Dog Night',
#   'ranking': 11,
#   'songurl': ['/wiki/Mama_Told_Me_Not_to_Come'],
#   'title': '"Mama Told Me (Not to Come)"',
#   'url': ['/wiki/Three_Dog_Night']},
#  {'band_singer': 'Ray Stevens',
#   'ranking': 12,
#   'songurl': ['/wiki/Everything_Is_Beautiful'],
#   'title': '"Everything Is Beautiful"',
#   'url': ['/wiki/Ray_Stevens']},
#  {'band_singer': 'Bread',
#   'ranking': 13,
#   'songurl': ['/wiki/Make_It_with_You'],
#   'title': '"Make It with You"',
#   'url': ['/wiki/Bread_(band)']},
#  {'band_singer': 'Vanity Fare',
#   'ranking': 14,
#   'songurl': ['/wiki/Hitchin%27_a_Ride_(Vanity_Fare_song)'],
#   'title': '"Hitchin\' a Ride"',
#   'url': ['/wiki/Vanity_Fare']},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 15,
#   'songurl': ['/wiki/ABC_(The_Jackson_5_song)'],
#   'title': '"ABC"',
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 16,
#   'songurl': ['/wiki/The_Love_You_Save'],
#   'title': '"The Love You Save"',
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': 'Neil Diamond',
#   'ranking': 17,
#   'songurl': ['/wiki/Cracklin%27_Rosie'],
#   'title': '"Cracklin\' Rosie"',
#   'url': ['/wiki/Neil_Diamond']},
#  {'band_singer': 'Dawn',
#   'ranking': 18,
#   'songurl': ['/wiki/Candida_(song)'],
#   'title': '"Candida"',
#   'url': ['/wiki/Tony_Orlando_and_Dawn']},
#  {'band_singer': 'Sly & the Family Stone',
#   'ranking': 19,
#   'songurl': ['/wiki/Thank_You_(Falettinme_Be_Mice_Elf_Agin)'],
#   'title': '"Thank You (Falettinme Be Mice Elf Agin)"',
#   'url': ['/wiki/Sly_%26_the_Family_Stone']},
#  {'band_singer': 'Eric Burdon & War',
#   'ranking': 20,
#   'songurl': ['/wiki/Spill_the_Wine'],
#   'title': '"Spill the Wine"',
#   'url': ['/wiki/Eric_Burdon', '/wiki/War_(band)']},
#  {'band_singer': 'Five Stairsteps',
#   'ranking': 21,
#   'songurl': ['/wiki/O-o-h_Child'],
#   'title': '"O-o-h Child"',
#   'url': ['/wiki/Five_Stairsteps']},
#  {'band_singer': 'Norman Greenbaum',
#   'ranking': 22,
#   'songurl': ['/wiki/Spirit_in_the_Sky'],
#   'title': '"Spirit in the Sky"',
#   'url': ['/wiki/Norman_Greenbaum']},
#  {'band_singer': 'Melanie',
#   'ranking': 23,
#   'songurl': ['/wiki/Lay_Down_(Candles_in_the_Rain)'],
#   'title': '"Lay Down (Candles in the Rain)"',
#   'url': ['/wiki/Melanie_Safka']},
#  {'band_singer': 'The Temptations',
#   'ranking': 24,
#   'songurl': ['/wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)'],
#   'title': '"Ball of Confusion (That\'s What the World Is Today)"',
#   'url': ['/wiki/The_Temptations']},
#  {'band_singer': 'The Moments',
#   'ranking': 25,
#   'songurl': ['/wiki/Love_on_a_Two-Way_Street'],
#   'title': '"Love on a Two-Way Street"',
#   'url': ['/wiki/Ray,_Goodman_%26_Brown']},
#  {'band_singer': 'The Poppy Family',
#   'ranking': 26,
#   'songurl': ['/wiki/Which_Way_You_Goin%27_Billy%3F_(song)'],
#   'title': '"Which Way You Goin\' Billy?"',
#   'url': ['/wiki/The_Poppy_Family']},
#  {'band_singer': 'Free',
#   'ranking': 27,
#   'songurl': ['/wiki/All_Right_Now'],
#   'title': '"All Right Now"',
#   'url': ['/wiki/Free_(band)']},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 28,
#   'songurl': ['/wiki/I_Want_You_Back'],
#   'title': '"I Want You Back"',
#   'url': ['/wiki/The_Jackson_5']},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': 29,
#   'songurl': ['/wiki/Julie,_Do_Ya_Love_Me'],
#   'title': '"Julie, Do Ya Love Me"',
#   'url': ['/wiki/Bobby_Sherman']},
#  {'band_singer': 'Sugarloaf',
#   'ranking': 30,
#   'songurl': ['/wiki/Green-Eyed_Lady'],
#   'title': '"Green-Eyed Lady"',
#   'url': ['/wiki/Sugarloaf_(band)']},
#  {'band_singer': 'Stevie Wonder',
#   'ranking': 31,
#   'songurl': ['/wiki/Signed,_Sealed,_Delivered_I%27m_Yours'],
#   'title': '"Signed, Sealed, Delivered I\'m Yours"',
#   'url': ['/wiki/Stevie_Wonder']},
#  {'band_singer': 'Blues Image',
#   'ranking': 32,
#   'songurl': ['/wiki/Ride_Captain_Ride'],
#   'title': '"Ride Captain Ride"',
#   'url': ['/wiki/Blues_Image']},
#  {'band_singer': 'Shocking Blue',
#   'ranking': 33,
#   'songurl': ['/wiki/Venus_(Shocking_Blue_song)'],
#   'title': '"Venus"',
#   'url': ['/wiki/Shocking_Blue']},
#  {'band_singer': 'John Lennon',
#   'ranking': 34,
#   'songurl': ['/wiki/Instant_Karma!'],
#   'title': '"Instant Karma!"',
#   'url': ['/wiki/John_Lennon']},
#  {'band_singer': 'Clarence Carter',
#   'ranking': 35,
#   'songurl': ['/wiki/Patches_(Chairmen_of_the_Board_song)'],
#   'title': '"Patches"',
#   'url': ['/wiki/Clarence_Carter']},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 36,
#   'songurl': ['/wiki/Lookin%27_out_My_Back_Door'],
#   'title': '"Lookin\' out My Back Door"',
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': 'Brook Benton',
#   'ranking': 37,
#   'songurl': ['/wiki/Rainy_Night_in_Georgia'],
#   'title': '"Rainy Night in Georgia"',
#   'url': ['/wiki/Brook_Benton']},
#  {'band_singer': 'Kenny Rogers & The First Edition',
#   'ranking': 38,
#   'songurl': [],
#   'title': '"Something\'s Burning"',
#   'url': ['/wiki/Kenny_Rogers', '/wiki/The_First_Edition_(band)']},
#  {'band_singer': 'Chairmen of the Board',
#   'ranking': 39,
#   'songurl': ['/wiki/Give_Me_Just_a_Little_More_Time'],
#   'title': '"Give Me Just a Little More Time"',
#   'url': ['/wiki/Chairmen_of_the_Board']},
#  {'band_singer': 'Edison Lighthouse',
#   'ranking': 40,
#   'songurl': ['/wiki/Love_Grows_(Where_My_Rosemary_Goes)'],
#   'title': '"Love Grows (Where My Rosemary Goes)"',
#   'url': ['/wiki/Edison_Lighthouse']},
#  {'band_singer': 'The Beatles',
#   'ranking': 41,
#   'songurl': ['/wiki/The_Long_and_Winding_Road'],
#   'title': '"The Long and Winding Road"',
#   'url': ['/wiki/The_Beatles']},
#  {'band_singer': 'Anne Murray',
#   'ranking': 42,
#   'songurl': ['/wiki/Snowbird_(song)'],
#   'title': '"Snowbird"',
#   'url': ['/wiki/Anne_Murray']},
#  {'band_singer': 'Marmalade',
#   'ranking': 43,
#   'songurl': ['/wiki/Reflections_of_My_Life'],
#   'title': '"Reflections of My Life"',
#   'url': ['/wiki/Marmalade_(band)']},
#  {'band_singer': 'Eddie Holman',
#   'ranking': 44,
#   'songurl': ['/wiki/Hey_There_Lonely_Girl'],
#   'title': '"Hey There Lonely Girl"',
#   'url': ['/wiki/Eddie_Holman']},
#  {'band_singer': 'The Jaggerz',
#   'ranking': 45,
#   'songurl': ['/wiki/The_Rapper'],
#   'title': '"The Rapper"',
#   'url': ['/wiki/The_Jaggerz']},
#  {'band_singer': 'The Hollies',
#   'ranking': 46,
#   'songurl': ['/wiki/He_Ain%27t_Heavy,_He%27s_My_Brother'],
#   'title': '"He Ain\'t Heavy, He\'s My Brother"',
#   'url': ['/wiki/The_Hollies']},
#  {'band_singer': "Alive N Kickin'",
#   'ranking': 47,
#   'songurl': ['/wiki/Tighter,_Tighter'],
#   'title': '"Tighter, Tighter"',
#   'url': ['/wiki/Alive_N_Kickin%27']},
#  {'band_singer': 'Badfinger',
#   'ranking': 48,
#   'songurl': ['/wiki/Come_and_Get_It_(Badfinger_song)'],
#   'title': '"Come and Get It"',
#   'url': ['/wiki/Badfinger']},
#  {'band_singer': 'Simon & Garfunkel',
#   'ranking': 49,
#   'songurl': ['/wiki/Cecilia_(Simon_%26_Garfunkel_song)'],
#   'title': '"Cecilia"',
#   'url': ['/wiki/Simon_%26_Garfunkel']},
#  {'band_singer': None,
#   'ranking': 50,
#   'songurl': ['/wiki/Love_Land_(song)'],
#   'title': '"Love Land"',
#   'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#  {'band_singer': 'Tyrone Davis',
#   'ranking': 51,
#   'songurl': ['/wiki/Turn_Back_the_Hands_of_Time_(song)'],
#   'title': '"Turn Back the Hands of Time"',
#   'url': ['/wiki/Tyrone_Davis']},
#  {'band_singer': 'The Kinks',
#   'ranking': 52,
#   'songurl': ['/wiki/Lola_(song)'],
#   'title': '"Lola"',
#   'url': ['/wiki/The_Kinks']},
#  {'band_singer': 'Mungo Jerry',
#   'ranking': 53,
#   'songurl': ['/wiki/In_the_Summertime_(Mungo_Jerry_song)'],
#   'title': '"In the Summertime"',
#   'url': ['/wiki/Mungo_Jerry']},
#  {'band_singer': 'R. Dean Taylor',
#   'ranking': 54,
#   'songurl': ['/wiki/Indiana_Wants_Me'],
#   'title': '"Indiana Wants Me"',
#   'url': ['/wiki/R._Dean_Taylor']},
#  {'band_singer': 'Rare Earth',
#   'ranking': 55,
#   'songurl': ['/wiki/(I_Know)_I%27m_Losing_You'],
#   'title': '"(I Know) I\'m Losing You"',
#   'url': ['/wiki/Rare_Earth_(band)']},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': 56,
#   'songurl': ['/wiki/Easy_Come,_Easy_Go_(Bobby_Sherman_song)'],
#   'title': '"Easy Come, Easy Go"',
#   'url': ['/wiki/Bobby_Sherman']},
#  {'band_singer': None,
#   'ranking': 57,
#   'songurl': ['/wiki/Express_Yourself_(Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band_song)'],
#   'title': '"Express Yourself"',
#   'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#  {'band_singer': 'The Four Tops',
#   'ranking': 58,
#   'songurl': ['/wiki/Still_Water_(Love)'],
#   'title': '"Still Water (Love)"',
#   'url': ['/wiki/The_Four_Tops']},
#  {'band_singer': 'Chicago',
#   'ranking': 59,
#   'songurl': ['/wiki/Make_Me_Smile'],
#   'title': '"Make Me Smile"',
#   'url': ['/wiki/Chicago_(band)']},
#  {'band_singer': 'Frijid Pink',
#   'ranking': 60,
#   'songurl': ['/wiki/The_House_of_the_Rising_Sun'],
#   'title': '"The House of the Rising Sun"',
#   'url': ['/wiki/Frijid_Pink']},
#  {'band_singer': 'Chicago',
#   'ranking': 61,
#   'songurl': ['/wiki/25_or_6_to_4'],
#   'title': '"25 or 6 to 4"',
#   'url': ['/wiki/Chicago_(band)']},
#  {'band_singer': 'White Plains',
#   'ranking': 62,
#   'songurl': ['/wiki/My_Baby_Loves_Lovin%27'],
#   'title': '"My Baby Loves Lovin\'"',
#   'url': ['/wiki/White_Plains_(band)']},
#  {'band_singer': 'The Friends of Distinction',
#   'ranking': 63,
#   'songurl': ['/wiki/Love_or_Let_Me_Be_Lonely'],
#   'title': '"Love or Let Me Be Lonely"',
#   'url': ['/wiki/The_Friends_of_Distinction']},
#  {'band_singer': 'The Brotherhood of Man',
#   'ranking': 64,
#   'songurl': ['/wiki/United_We_Stand_(song)'],
#   'title': '"United We Stand"',
#   'url': ['/wiki/The_Brotherhood_of_Man']},
#  {'band_singer': 'The Carpenters',
#   'ranking': 65,
#   'songurl': ['/wiki/We%27ve_Only_Just_Begun'],
#   'title': '"We\'ve Only Just Begun"',
#   'url': ['/wiki/The_Carpenters']},
#  {'band_singer': 'Mark Lindsay',
#   'ranking': 66,
#   'songurl': ['/wiki/Arizona_(song)'],
#   'title': '"Arizona"',
#   'url': ['/wiki/Mark_Lindsay']},
#  {'band_singer': 'James Taylor',
#   'ranking': 67,
#   'songurl': ['/wiki/Fire_and_Rain_(song)'],
#   'title': '"Fire and Rain"',
#   'url': ['/wiki/James_Taylor']},
#  {'band_singer': None,
#   'ranking': 68,
#   'songurl': ['/wiki/Groovy_Situation'],
#   'title': '"Groovy Situation"',
#   'url': ['/wiki/Gene_Chandler']},
#  {'band_singer': 'Santana',
#   'ranking': 69,
#   'songurl': ['/wiki/Evil_Ways'],
#   'title': '"Evil Ways"',
#   'url': ['/wiki/Santana_(band)']},
#  {'band_singer': 'The Guess Who',
#   'ranking': 70,
#   'songurl': ['/wiki/No_Time_(The_Guess_Who_song)'],
#   'title': '"No Time"',
#   'url': ['/wiki/The_Guess_Who']},
#  {'band_singer': 'The Delfonics',
#   'ranking': 71,
#   'songurl': ['/wiki/Didn%27t_I_(Blow_Your_Mind_This_Time)'],
#   'title': '"Didn\'t I (Blow Your Mind This Time)"',
#   'url': ['/wiki/The_Delfonics']},
#  {'band_singer': 'Elvis Presley',
#   'ranking': 72,
#   'songurl': ['/wiki/The_Wonder_of_You'],
#   'title': '"The Wonder of You"',
#   'url': ['/wiki/Elvis_Presley']},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 73,
#   'songurl': ['/wiki/Up_Around_the_Bend'],
#   'title': '"Up Around the Bend"',
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': 'Ronnie Dyson',
#   'ranking': 74,
#   'songurl': ['/wiki/(If_You_Let_Me_Make_Love_To_You_Then)_Why_Can%27t_I_Touch_You%3F'],
#   'title': '"(If You Let Me Make Love To You Then) Why Can\'t I Touch You?"',
#   'url': ['/wiki/Ronnie_Dyson']},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 75,
#   'songurl': ['/wiki/I_Just_Can%27t_Help_Believing'],
#   'title': '"I Just Can\'t Help Believing"',
#   'url': ['/wiki/B.J._Thomas']},
#  {'band_singer': 'The Spinners',
#   'ranking': 76,
#   'songurl': ['/wiki/It%27s_a_Shame_(The_Spinners_song)'],
#   'title': '"It\'s a Shame"',
#   'url': ['/wiki/The_Spinners_(American_band)']},
#  {'band_singer': 'Bobbi Martin',
#   'ranking': 77,
#   'songurl': ['/wiki/For_the_Love_of_Him'],
#   'title': '"For the Love of Him"',
#   'url': ['/wiki/Bobbi_Martin']},
#  {'band_singer': 'Mountain',
#   'ranking': 78,
#   'songurl': ['/wiki/Mississippi_Queen'],
#   'title': '"Mississippi Queen"',
#   'url': ['/wiki/Mountain_(band)']},
#  {'band_singer': 'Ike & Tina Turner',
#   'ranking': 79,
#   'songurl': ['/wiki/I_Want_to_Take_You_Higher'],
#   'title': '"I Want to Take You Higher"',
#   'url': ['/wiki/Ike_%26_Tina_Turner']},
#  {'band_singer': 'Joe Cocker',
#   'ranking': 80,
#   'songurl': ['/wiki/The_Letter_(The_Box_Tops_song)'],
#   'title': '"The Letter"',
#   'url': ['/wiki/Joe_Cocker']},
#  {'band_singer': 'Tee Set',
#   'ranking': 81,
#   'songurl': ['/wiki/Ma_Belle_Amie'],
#   'title': '"Ma Belle Amie"',
#   'url': ['/wiki/Tee_Set']},
#  {'band_singer': 'The Originals',
#   'ranking': 82,
#   'songurl': ['/wiki/The_Bells_(The_Originals_song)'],
#   'title': '"The Bells"',
#   'url': ['/wiki/The_Originals_(band)']},
#  {'band_singer': 'Christie',
#   'ranking': 83,
#   'songurl': ['/wiki/Yellow_River_(song)'],
#   'title': '"Yellow River"',
#   'url': ['/wiki/Christie_(band)']},
#  {'band_singer': '100 Proof (Aged in Soul)',
#   'ranking': 84,
#   'songurl': ['/wiki/Somebody%27s_Been_Sleeping'],
#   'title': '"Somebody\'s Been Sleeping"',
#   'url': ['/wiki/100_Proof_(Aged_in_Soul)']},
#  {'band_singer': 'The Ides of March',
#   'ranking': 85,
#   'songurl': ['/wiki/Vehicle_(song)'],
#   'title': '"Vehicle"',
#   'url': ['/wiki/The_Ides_of_March_(band)']},
#  {'band_singer': 'The Pipkins',
#   'ranking': 86,
#   'songurl': ['/wiki/Gimme_Dat_Ding_(song)'],
#   'title': '"Gimme Dat Ding"',
#   'url': ['/wiki/The_Pipkins']},
#  {'band_singer': 'Robin McNamara',
#   'ranking': 87,
#   'songurl': ['/wiki/Lay_a_Little_Lovin%27_on_Me'],
#   'title': '"Lay a Little Lovin\' on Me"',
#   'url': ['/wiki/Robin_McNamara']},
#  {'band_singer': 'The Supremes',
#   'ranking': 88,
#   'songurl': ['/wiki/Up_the_Ladder_to_the_Roof'],
#   'title': '"Up the Ladder to the Roof"',
#   'url': ['/wiki/The_Supremes']},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 89,
#   'songurl': ['/wiki/Travelin%27_Band'],
#   'title': '"Travelin\' Band"',
#   'url': ['/wiki/Creedence_Clearwater_Revival']},
#  {'band_singer': None,
#   'ranking': 90,
#   'songurl': ['/wiki/Come_Saturday_Morning_(song)'],
#   'title': '"Come Saturday Morning"',
#   'url': ['/wiki/The_Sandpipers']},
#  {'band_singer': 'The Temptations',
#   'ranking': 91,
#   'songurl': ['/wiki/Psychedelic_Shack_(song)'],
#   'title': '"Psychedelic Shack"',
#   'url': ['/wiki/The_Temptations']},
#  {'band_singer': 'Tom Jones',
#   'ranking': 92,
#   'songurl': ['/wiki/Without_Love_(There_Is_Nothing)'],
#   'title': '"Without Love (There Is Nothing)"',
#   'url': ['/wiki/Tom_Jones_(singer)']},
#  {'band_singer': 'Pacific Gas & Electric',
#   'ranking': 93,
#   'songurl': ['/wiki/Are_You_Ready%3F_(Pacific_Gas_%26_Electric_song)'],
#   'title': '"Are You Ready?"',
#   'url': ['/wiki/Pacific_Gas_%26_Electric_(band)']},
#  {'band_singer': 'Crosby, Stills, Nash & Young',
#   'ranking': 94,
#   'songurl': ['/wiki/Woodstock_(song)'],
#   'title': '"Woodstock"',
#   'url': ['/wiki/Crosby,_Stills,_Nash_%26_Young']},
#  {'band_singer': 'Dionne Warwick',
#   'ranking': 95,
#   'songurl': ['/wiki/I%27ll_Never_Fall_in_Love_Again'],
#   'title': '"I\'ll Never Fall in Love Again"',
#   'url': ['/wiki/Dionne_Warwick']},
#  {'band_singer': 'The New Seekers',
#   'ranking': 96,
#   'songurl': [],
#   'title': '"Look What They\'ve Done to My Song Ma"',
#   'url': ['/wiki/The_New_Seekers']},
#  {'band_singer': 'Joe South',
#   'ranking': 97,
#   'songurl': ['/wiki/Walk_A_Mile_In_My_Shoes'],
#   'title': '"Walk A Mile In My Shoes"',
#   'url': ['/wiki/Joe_South']},
#  {'band_singer': 'B.B. King',
#   'ranking': 98,
#   'songurl': ['/wiki/The_Thrill_Is_Gone_(1951_song)'],
#   'title': '"The Thrill Is Gone"',
#   'url': ['/wiki/B.B._King']},
#  {'band_singer': 'Glen Campbell',
#   'ranking': 99,
#   'songurl': ['/wiki/It%27s_Only_Make_Believe'],
#   'title': '"It\'s Only Make Believe"',
#   'url': ['/wiki/Glen_Campbell']},
#  {'band_singer': 'Aretha Franklin',
#   'ranking': 100,
#   'songurl': ['/wiki/Call_Me_(Aretha_Franklin_song)'],
#   'title': '"Call Me"',
#   'url': ['/wiki/Aretha_Franklin']}]

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %%
import time
start = 1992
yearstext = dict()
for i in range(23):
    year = str(start + i)
    req = requests.get(" http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + year)
    page = req.text
    soup = BeautifulSoup(page, 'html.parser')
    yearstext[int(year)] = soup
    time.sleep(12)
yearstext

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""

# %%
def parse_year(the_year, year_dict):
    full_page = year_dict.get(the_year)
    tables_wikitable = full_page.find_all("table", "wikitable")
    rows = [row for row in tables_wikitable[0].find_all("tr")]
    values = []
    for row in rows[1:]:
        count = 0
        d_1 = dict()
        for td in row.find_all("td"):
            count += 1
            text = td.get_text()
            th = row.find("th")
            rank = int(th.get_text())
            d_1['ranking'] = rank
            if count == 1:
                song_url_list = []
                for link in td.find_all("a"):
                    song_url_list.append(link.get("href"))
                if "/" in text:
                    songs = text.split("/")
                    d_1['titletext'] = songs
                else:
                    d_1['titletext'] = text
                if len(song_url_list) == 0:
                    song_url_list.append(None)
                d_1['songurl'] = song_url_list
            elif count == 2:
                artist_url_list = []
                for link in td.find_all("a"):
                    artist_url_list.append(link.get("href"))
                if "featuring" in text and "and" in text:
                    text1 = text.split(" featuring ")
                    #text1 = ["Kanye", "TPain and Taylor Swift"]
                    text2 = text1[1].split(" and ")
                    #text2 = ["TPain", "Taylor Swift"]
                    text2.insert(0, text1[0])
                    text = text2
                elif "featuring" in text and len(artist_url_list) > 1:
                    text = text.split(" featuring ")
                elif "and" in text and len(artist_url_list) > 1:
                    text = text.split(" and ")
                elif "&" in text and len(artist_url_list) > 1:
                    text = text.split(" & ")
                d_1['band_singer'] = text
                d_1['url'] = artist_url_list
                values.append(d_1)
                d_1 = dict()
    return values
parse_year(1997, yearstext)[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ec53fc0082be> in <module>()
#      47                 d_1 = dict()
#      48     return values
# ---> 49 parse_year(1997, yearstext)[:5]
#
# NameError: name 'yearstext' is not defined

# %%
yearinfo = {k: parse_year(k, yearstext) for k, v in yearstext.items()}

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("data/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("data/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %%
temp_list = []
for key, value in yearinfo.items():
    temp = pd.DataFrame.from_dict(value)
    temp['year'] = key
    temp_list.append(temp)
flatframe = pd.concat(temp_list)
cols = flatframe.columns.tolist()
neworder = [5,0,1,2,3,4]
cols = [ cols[i] for i in neworder]
flatframe = flatframe[cols]
flatframe
# Out:
#     year                                        band_singer  ranking                                            songurl                                titletext                                                url
# 0   1992                                        Boyz II Men        1                            [/wiki/End_of_the_Road]                        "End of the Road"                                [/wiki/Boyz_II_Men]
# 1   1992                                      Sir Mix-a-Lot        2                              [/wiki/Baby_Got_Back]                          "Baby Got Back"                              [/wiki/Sir_Mix-a-Lot]
# 2   1992                                         Kris Kross        3                                       [/wiki/Jump]                                   "Jump"                                 [/wiki/Kris_Kross]
# 3   1992                                   Vanessa Williams        4                     [/wiki/Save_the_Best_for_Last]                 "Save the Best for Last"                        [/wiki/Vanessa_L._Williams]
# 4   1992                                                TLC        5                             [/wiki/Baby-Baby-Baby]                         "Baby-Baby-Baby"                                 [/wiki/TLC_(band)]
# 5   1992                                       Eric Clapton        6                            [/wiki/Tears_in_Heaven]                        "Tears in Heaven"                               [/wiki/Eric_Clapton]
# 6   1992                                           En Vogue        7  [/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)]  "My Lovin' (You're Never Gonna Get It)"                                   [/wiki/En_Vogue]
# 7   1992                              Red Hot Chili Peppers        8                           [/wiki/Under_the_Bridge]                       "Under the Bridge"                      [/wiki/Red_Hot_Chili_Peppers]
# 8   1992                                      Color Me Badd        9                                 [/wiki/All_4_Love]                             "All 4 Love"                              [/wiki/Color_Me_Badd]
# 9   1992                                         Jon Secada       10         [/wiki/Just_Another_Day_(Jon_Secada_song)]                       "Just Another Day"                                 [/wiki/Jon_Secada]
# 10  1992                                            Shanice       11                          [/wiki/I_Love_Your_Smile]                      "I Love Your Smile"                                    [/wiki/Shanice]
# 11  1992                                            Mr. Big       12                             [/wiki/To_Be_with_You]                         "To Be with You"                             [/wiki/Mr._Big_(band)]
# 12  1992                                    Right Said Fred       13                             [/wiki/I%27m_Too_Sexy]                           "I'm Too Sexy"                            [/wiki/Right_Said_Fred]
# 93  2014                            [Zedd, Hayley Williams]       94                 [/wiki/Stay_the_Night_(Zedd_song)]                         "Stay the Night"     [/wiki/Zedd_(musician), /wiki/Hayley_Williams]
# 94  2014                                            Beyoncé       95                           [/wiki/Partition_(song)]                              "Partition"                               [/wiki/Beyonc%C3%A9]
# 95  2014                  [ScHoolboy Q, BJ the Chicago Kid]       96                              [/wiki/Studio_(song)]                                 "Studio"      [/wiki/ScHoolboy_Q, /wiki/BJ_the_Chicago_Kid]
# 96  2014                                              Drake       97                    [/wiki/0_to_100_/_The_Catch_Up]             ["0 to 100 ,  The Catch Up"]                             [/wiki/Drake_(rapper)]
# 97  2014                                          Lee Brice       98           [/wiki/I_Don%27t_Dance_(Lee_Brice_song)]                          "I Don't Dance"                                  [/wiki/Lee_Brice]
# 98  2014                [Miranda Lambert, Carrie Underwood]       99                            [/wiki/Somethin%27_Bad]                          "Somethin' Bad"    [/wiki/Miranda_Lambert, /wiki/Carrie_Underwood]
# 99  2014                                        Miley Cyrus      100                                  [/wiki/Adore_You]                              "Adore You"                                [/wiki/Miley_Cyrus]
#
# [2300 rows x 6 columns]

# %%
flatframe.dtypes
# Out:
# year           object
# band_singer    object
# ranking         int64
# songurl        object
# titletext      object
# url            object
# dtype: object

# %%
flatframe['year'] = flatframe['year'].astype(int)
flatframe.dtypes
# Out:
# year            int32
# band_singer    object
# ranking         int64
# songurl        object
# titletext      object
# url            object
# dtype: object

# %%
print(np.sum([flatframe.year.isnull()]))
print(np.sum([flatframe.band_singer.isnull()]))
print(np.sum([flatframe.ranking.isnull()]))
print(np.sum([flatframe.titletext.isnull()]))
print(np.sum([flatframe.songurl.isnull()]))
print(np.sum([flatframe.url.isnull()]))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
rows = []
for i, row in flatframe.iterrows():
    if isinstance(row.band_singer, list):
        if isinstance(row.url, list) and len(row.url) == len(row.band_singer):
            index = 0
            for a in row.band_singer:
                rows.append([row.year, a, row.ranking, row.songurl, row.titletext, row.url[index]])
                index += 1
        elif isinstance(row.url, list):
            for a in row.band_singer:
                rows.append([row.year, a, row.ranking, row.songurl, row.titletext, row.url[0]])
        else:
            for a in row.band_singer:
                rows.append([row.year, a, row.ranking, row.songurl, row.titletext, None])
    elif len(row.url) != 0:
        rows.append([row.year, row.band_singer, row.ranking, row.songurl, row.titletext, row.url[0]])
    else:
        rows.append([row.year, row.band_singer, row.ranking, row.songurl, row.titletext, None])

        
flatframe = pd.DataFrame(rows, columns = cols)
flatframe
# Out:
#       year                band_singer  ranking                                            songurl                                titletext                              url
# 0     1992                Boyz II Men        1                            [/wiki/End_of_the_Road]                        "End of the Road"                /wiki/Boyz_II_Men
# 1     1992              Sir Mix-a-Lot        2                              [/wiki/Baby_Got_Back]                          "Baby Got Back"              /wiki/Sir_Mix-a-Lot
# 2     1992                 Kris Kross        3                                       [/wiki/Jump]                                   "Jump"                 /wiki/Kris_Kross
# 3     1992           Vanessa Williams        4                     [/wiki/Save_the_Best_for_Last]                 "Save the Best for Last"        /wiki/Vanessa_L._Williams
# 4     1992                        TLC        5                             [/wiki/Baby-Baby-Baby]                         "Baby-Baby-Baby"                 /wiki/TLC_(band)
# 5     1992               Eric Clapton        6                            [/wiki/Tears_in_Heaven]                        "Tears in Heaven"               /wiki/Eric_Clapton
# 6     1992                   En Vogue        7  [/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)]  "My Lovin' (You're Never Gonna Get It)"                   /wiki/En_Vogue
# 7     1992      Red Hot Chili Peppers        8                           [/wiki/Under_the_Bridge]                       "Under the Bridge"      /wiki/Red_Hot_Chili_Peppers
# 8     1992              Color Me Badd        9                                 [/wiki/All_4_Love]                             "All 4 Love"              /wiki/Color_Me_Badd
# 9     1992                 Jon Secada       10         [/wiki/Just_Another_Day_(Jon_Secada_song)]                       "Just Another Day"                 /wiki/Jon_Secada
# 10    1992                    Shanice       11                          [/wiki/I_Love_Your_Smile]                      "I Love Your Smile"                    /wiki/Shanice
# 11    1992                    Mr. Big       12                             [/wiki/To_Be_with_You]                         "To Be with You"             /wiki/Mr._Big_(band)
# 12    1992            Right Said Fred       13                             [/wiki/I%27m_Too_Sexy]                           "I'm Too Sexy"            /wiki/Right_Said_Fred
# 13    1992            Michael Jackson       14                             [/wiki/Black_or_White]                         "Black or White"            /wiki/Michael_Jackson
# 14    1992            Billy Ray Cyrus       15                          [/wiki/Achy_Breaky_Heart]                      "Achy Breaky Heart"            /wiki/Billy_Ray_Cyrus
# 15    1992               Mariah Carey       16  [/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Ma...                          "I'll Be There"               /wiki/Mariah_Carey
# 16    1992              Guns N' Roses       17                              [/wiki/November_Rain]                          "November Rain"            /wiki/Guns_N%27_Roses
# Taylor Swift           17
# Kelly Clarkson         17
# Katy Perry             17
# The Black Eyed Peas    16
# Madonna                16
# Name: band_singer, dtype: int64

# %%
counts_15.plot.bar()

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
scores = flatframe['ranking'].apply(lambda x: 101 - x)
flatframe['score'] = scores
flatframe
# Out:
#       year                band_singer  ranking                                            songurl                                titletext                              url  score
# 0     1992                Boyz II Men        1                            [/wiki/End_of_the_Road]                        "End of the Road"                /wiki/Boyz_II_Men    100
# 1     1992              Sir Mix-a-Lot        2                              [/wiki/Baby_Got_Back]                          "Baby Got Back"              /wiki/Sir_Mix-a-Lot     99
# 2     1992                 Kris Kross        3                                       [/wiki/Jump]                                   "Jump"                 /wiki/Kris_Kross     98
# 3     1992           Vanessa Williams        4                     [/wiki/Save_the_Best_for_Last]                 "Save the Best for Last"        /wiki/Vanessa_L._Williams     97
# 4     1992                        TLC        5                             [/wiki/Baby-Baby-Baby]                         "Baby-Baby-Baby"                 /wiki/TLC_(band)     96
# 5     1992               Eric Clapton        6                            [/wiki/Tears_in_Heaven]                        "Tears in Heaven"               /wiki/Eric_Clapton     95
# 6     1992                   En Vogue        7  [/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)]  "My Lovin' (You're Never Gonna Get It)"                   /wiki/En_Vogue     94
# 7     1992      Red Hot Chili Peppers        8                           [/wiki/Under_the_Bridge]                       "Under the Bridge"      /wiki/Red_Hot_Chili_Peppers     93
# 8     1992              Color Me Badd        9                                 [/wiki/All_4_Love]                             "All 4 Love"              /wiki/Color_Me_Badd     92
# 9     1992                 Jon Secada       10         [/wiki/Just_Another_Day_(Jon_Secada_song)]                       "Just Another Day"                 /wiki/Jon_Secada     91
# 10    1992                    Shanice       11                          [/wiki/I_Love_Your_Smile]                      "I Love Your Smile"                    /wiki/Shanice     90
# 11    1992                    Mr. Big       12                             [/wiki/To_Be_with_You]                         "To Be with You"             /wiki/Mr._Big_(band)     89
# 12    1992            Right Said Fred       13                             [/wiki/I%27m_Too_Sexy]                           "I'm Too Sexy"            /wiki/Right_Said_Fred     88
# 13    1992            Michael Jackson       14                             [/wiki/Black_or_White]                         "Black or White"            /wiki/Michael_Jackson     87
# 14    1992            Billy Ray Cyrus       15                          [/wiki/Achy_Breaky_Heart]                      "Achy Breaky Heart"            /wiki/Billy_Ray_Cyrus     86
# 15    1992               Mariah Carey       16  [/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Ma...                          "I'll Be There"               /wiki/Mariah_Carey     85
# 16    1992              Guns N' Roses       17                              [/wiki/November_Rain]                          "November Rain"            /wiki/Guns_N%27_Roses     84
# 17    1992               Tom Cochrane       18                          [/wiki/Life_Is_a_Highway]                      "Life Is a Highway"               /wiki/Tom_Cochrane     83
# 2937  2014                  Lil Wayne       89                [/wiki/Believe_Me_(Lil_Wayne_song)]                             "Believe Me"                  /wiki/Lil_Wayne     12
# 2938  2014                      Drake       89                [/wiki/Believe_Me_(Lil_Wayne_song)]                             "Believe Me"             /wiki/Drake_(rapper)     12
# 2939  2014          Mike WiLL Made-It       90                                  [/wiki/23_(song)]                                     "23"          /wiki/Mike_WiLL_Made-It     11
# 2940  2014  Miley Cyrus, Wiz Khalifa,       90                                  [/wiki/23_(song)]                                     "23"          /wiki/Mike_WiLL_Made-It     11
# 2941  2014                    Juicy J       90                                  [/wiki/23_(song)]                                     "23"          /wiki/Mike_WiLL_Made-It     11
# 2942  2014                  Jake Owen       91                                 [/wiki/Beachin%27]                               "Beachin'"                  /wiki/Jake_Owen     10
# 2943  2014    Macklemore & Ryan Lewis       92                                [/wiki/White_Walls]                            "White Walls"  /wiki/Macklemore_%26_Ryan_Lewis      9
# 2944  2014                ScHoolboy Q       92                                [/wiki/White_Walls]                            "White Walls"                /wiki/ScHoolboy_Q      9
# 2945  2014                     Hollis       92                                [/wiki/White_Walls]                            "White Walls"            /wiki/Hollis_(singer)      9
# 2946  2014        5 Seconds of Summer       93                       [/wiki/She_Looks_So_Perfect]                   "She Looks So Perfect"        /wiki/5_Seconds_of_Summer      8
# 2947  2014                       Zedd       94                 [/wiki/Stay_the_Night_(Zedd_song)]                         "Stay the Night"            /wiki/Zedd_(musician)      7
# 2948  2014            Hayley Williams       94                 [/wiki/Stay_the_Night_(Zedd_song)]                         "Stay the Night"            /wiki/Hayley_Williams      7
# 2949  2014                    Beyoncé       95                           [/wiki/Partition_(song)]                              "Partition"               /wiki/Beyonc%C3%A9      6
# 2950  2014                ScHoolboy Q       96                              [/wiki/Studio_(song)]                                 "Studio"                /wiki/ScHoolboy_Q      5
# 2951  2014         BJ the Chicago Kid       96                              [/wiki/Studio_(song)]                                 "Studio"         /wiki/BJ_the_Chicago_Kid      5
# 2952  2014                      Drake       97                    [/wiki/0_to_100_/_The_Catch_Up]             ["0 to 100 ,  The Catch Up"]             /wiki/Drake_(rapper)      4
# 2953  2014                  Lee Brice       98           [/wiki/I_Don%27t_Dance_(Lee_Brice_song)]                          "I Don't Dance"                  /wiki/Lee_Brice      3
# 2954  2014            Miranda Lambert       99                            [/wiki/Somethin%27_Bad]                          "Somethin' Bad"            /wiki/Miranda_Lambert      2
# 2955  2014           Carrie Underwood       99                            [/wiki/Somethin%27_Bad]                          "Somethin' Bad"           /wiki/Carrie_Underwood      2
# 2956  2014                Miley Cyrus      100                                  [/wiki/Adore_You]                              "Adore You"                /wiki/Miley_Cyrus      1
#
# [2957 rows x 7 columns]

# %%
artist_scores = flatframe['score'].groupby(flatframe['band_singer']).sum()
artist_scores = artist_scores.sort_values(ascending = False)
artist_scores_20 = artist_scores[:20]
artist_scores_20
# Out:
# band_singer
# Rihanna              2103
# Usher                1834
# Mariah Carey         1727
# Lil Wayne            1428
# Ludacris             1361
# Katy Perry           1264
# Jay-Z                1258
# Justin Timberlake    1191
# Chris Brown          1166
# Beyoncé              1160
# Pink                 1141
# Kanye West           1133
# Akon                 1041
# R. Kelly             1023
# Alicia Keys          1010
# 50 Cent               982
# Bruno Mars            972
# Nelly                 957
# Maroon 5              957
# Janet Jackson         952
# Name: score, dtype: int64

# %%
artist_scores_20.plot.bar()

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# The most significant difference that I noticed, was the position of Katy Perry, who went from being pretty far behind the top artists in 18th place, to 6th place. Also, Mariah Carey's position improved by two spots on the second chart, where she holds a fairly large margin over Lil Wayne. I think that these artists shifted places because some of them, like Katy Perry and Mariah Carey, play pop music that has a much more general appeal than some other artists. So they might not show up on the charts as often, because they aren't as prolific as other artists, but when they do show up, they usually take a very high spot.

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
flatframe=flatframe.sort_values('year')
flatframe.head()

# %% [markdown]
# #### Pulling and saving the data

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("data/artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("data/artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %%
def singer_band_info(url, page_text):
    if type(page_text) != str:
        return dict()
    soup = BeautifulSoup(page_text, 'html.parser')
    dict_1 = dict()
    infobox = soup.find('table', 'infobox')
    if infobox == None:
        return dict_1
    born = ''
    ya = ''
    for tr in infobox.find_all('tr'):
        for th in tr.find_all('th'):
            if 'Years' in th.get_text():
                ya_i = tr.td.get_text()
                ya = ya_i.replace('\n', ', ').strip()
            elif "Born" in th.get_text():
                bday = tr.td.find('span', 'bday')
                if bday != None:
                    born = bday.get_text()
    if born == '':
        born = False
    dict_1['url'] = url
    dict_1['born'] = born
    dict_1['ya'] = ya
    return dict_1                

            

singer_band_info('/wiki/Jay_Z', urlcache.get('/wiki/Jay_Z'))
# Out:
# {'born': '1969-12-04', 'url': '/wiki/Jay_Z', 'ya': '1986–present'}

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

# %% [markdown]
# #### 2.2  Merging this information in

# %%
singer_band_info_list = []
for url, text in urlcache.items():
    singer_band_info_list.append(singer_band_info(url, text))
singer_band_info_list[-10:]
# Out:
# [{'born': False, 'url': '/wiki/MKTO', 'ya': '2010 – 2017'},
#  {'born': False, 'url': '/wiki/Clean_Bandit', 'ya': '2008–present'},
#  {'born': '1989-10-20', 'url': '/wiki/Jess_Glynne', 'ya': '2012–present'},
#  {'born': '1986-04-01', 'url': '/wiki/Kid_Ink', 'ya': '2010–present'},
#  {'born': '1979-01-07', 'url': '/wiki/Aloe_Blacc', 'ya': '1995–present'},
#  {'born': False, 'url': '/wiki/Gente_de_Zona', 'ya': '2000–present'},
#  {'born': '1971-07-05', 'url': '/wiki/Descemer_Bueno', 'ya': '1990–present'},
#  {'born': False, 'url': '/wiki/American_Authors', 'ya': '2006–present'},
#  {'born': '1987-10-29', 'url': '/wiki/Tove_Lo', 'ya': '2006–present'},
#  {'born': '1990-11-26', 'url': '/wiki/Rita_Ora', 'ya': '2007–present'}]

# %%
info_df = pd.DataFrame(singer_band_info_list)
info_df
# Out:
#             born                                   url                                     ya
# 0          False                     /wiki/Boyz_II_Men                           1985–present
# 1          False                    /wiki/Ugly_Kid_Joe     , , , 1987–1997, 2010–present, , ,
# 2          False                        /wiki/The_Cure                           1976–present
# 3     1959-11-05                     /wiki/Bryan_Adams                           1975–present
# 4          False  /wiki/Marky_Mark_and_the_Funky_Bunch                              1989–1993
# 5          False                  /wiki/Genesis_(band)  , , , 1967–1998[4][5], 2006–2007, , ,
# 6          False    /wiki/Arrested_Development_(group)                1988–1996, 2000–present
# 7     1958-08-29                 /wiki/Michael_Jackson                              1964–2009
# 8          False                      /wiki/Kris_Kross              1991–2002, 2013 (reunion)
# 9     1951-04-13                    /wiki/Peabo_Bryson                           1976–present
# 10    1968-03-30                     /wiki/Celine_Dion                           1980–present
# 11    1965-10-14                     /wiki/Karyn_White                1985–2007, 2012–present
# 12    1969-09-06                   /wiki/CeCe_Peniston                           1991–present
# 13         False                              /wiki/U2                           1976–present
# 14         False         /wiki/The_Heights_(TV_series)
# 15    1963-06-25                  /wiki/George_Michael                              1981–2016
# 16    1963-09-16                    /wiki/Richard_Marx                           1980–present
# 17    1953-02-26                  /wiki/Michael_Bolton                           1975–present
# 18         False           /wiki/Toad_the_Wet_Sprocket          1986–1998, 2002, 2006–present
# 19    1960-11-25                       /wiki/Amy_Grant                           1976–present
# 20         False                       /wiki/P.M._Dawn                         1988–June 2016
# 21         False                         /wiki/Hi-Five                1989–1994, 2012–present
# 22         False                           /wiki/Snap!                1989–1996; 2000–present
# 23    1949-11-08                    /wiki/Bonnie_Raitt                           1971–present
# 24         False                         /wiki/Das_EFX                           1988–present
# 25         False                     /wiki/Def_Leppard                           1977–present
# 26         False                  /wiki/Mr._Big_(band)                1988–2002, 2009–present
# 27    1961-07-22                     /wiki/Keith_Sweat                           1975–present
# 28         False                        /wiki/En_Vogue                           1989–present
# 29         False               /wiki/Charles_%26_Eddie                              1990–1995
# ...          ...                                   ...                                    ...
# 991        False                       /wiki/Echosmith                           2009–present
# 992   1986-10-26                     /wiki/ScHoolboy_Q                           2009–present
# 993   1989-03-23               /wiki/Mike_WiLL_Made-It                           2005–present
# 994        False       /wiki/Macklemore_%26_Ryan_Lewis               2008–2017 (on hiatus)[1]
# 995        False                 /wiki/Hollis_(singer)                           2013–present
# 996        False             /wiki/5_Seconds_of_Summer                           2011–present
# 997   1984-11-23              /wiki/BJ_the_Chicago_Kid                           2001–present
# 998   1985-01-01                     /wiki/Naughty_Boy                           2005–present
# 999   1992-05-19              /wiki/Sam_Smith_(singer)                           2007–present
# 1000  1990-06-07                     /wiki/Iggy_Azalea                           2011–present
# 1001       False                   /wiki/Kongos_(band)                    2007 (2007)–present
# 1002       False               /wiki/Disclosure_(band)               2010–present (hiatus)[1]
# 1003       False                   /wiki/Nico_%26_Vinz                           2010–present
# 1004  1986-06-13                        /wiki/DJ_Snake                           2009–present
# 1005       False               /wiki/A_Great_Big_World                           2011–present
# 1006  1971-05-30                    /wiki/Idina_Menzel                           1985–present
# 1007       False                 /wiki/Bastille_(band)                           2010–present
# 1008  1975-04-05                         /wiki/Juicy_J                           1991–present
# 1009       False                          /wiki/Magic!                    2012 (2012)–present
# 1010  1993-12-22                  /wiki/Meghan_Trainor                           2009–present
# 1011       False                            /wiki/MKTO                            2010 – 2017
# 1012       False                    /wiki/Clean_Bandit                           2008–present
# 1013  1989-10-20                     /wiki/Jess_Glynne                           2012–present
# 1014  1986-04-01                         /wiki/Kid_Ink                           2010–present
# 1015  1979-01-07                      /wiki/Aloe_Blacc                           1995–present
# 1016       False                   /wiki/Gente_de_Zona                           2000–present
# 1017  1971-07-05                  /wiki/Descemer_Bueno                           1990–present
# 1018       False                /wiki/American_Authors                           2006–present
# 1019  1987-10-29                         /wiki/Tove_Lo                           2006–present
# 1020  1990-11-26                        /wiki/Rita_Ora                           2007–present
#
# [1021 rows x 3 columns]

# %%
largedf = pd.merge(flatframe, info_df, on='url')
largedf
# Out:
#       year                band_singer  ranking                                            songurl                                   titletext                              url  score        born                         ya
# 0     1992                Boyz II Men        1                            [/wiki/End_of_the_Road]                           "End of the Road"                /wiki/Boyz_II_Men    100       False               1985–present
# 1     1992                Boyz II Men       37  [/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yester...  "It's So Hard to Say Goodbye to Yesterday"                /wiki/Boyz_II_Men     64       False               1985–present
# 2     1992                Boyz II Men       84                                    [/wiki/Uhh_Ahh]                                   "Uhh Ahh"                /wiki/Boyz_II_Men     17       False               1985–present
# 3     1993                Boyz II Men       12  [/wiki/In_the_Still_of_the_Night_(1956_song)#B...                  "In the Still of the Nite"                /wiki/Boyz_II_Men     89       False               1985–present
# 4     1994                Boyz II Men        3                    [/wiki/I%27ll_Make_Love_to_You]                     "I'll Make Love to You"                /wiki/Boyz_II_Men     98       False               1985–present
# 5     1995                Boyz II Men        5                             [/wiki/On_Bended_Knee]                            "On Bended Knee"                /wiki/Boyz_II_Men     96       False               1985–present
# 6     1995                Boyz II Men       12                             [/wiki/Water_Runs_Dry]                            "Water Runs Dry"                /wiki/Boyz_II_Men     89       False               1985–present
# 7     1995                Boyz II Men       50                    [/wiki/I%27ll_Make_Love_to_You]                     "I'll Make Love to You"                /wiki/Boyz_II_Men     51       False               1985–present
# 8     1995                Boyz II Men       94               [/wiki/Thank_You_(Boyz_II_Men_song)]                                 "Thank You"                /wiki/Boyz_II_Men      7       False               1985–present
# 9     1996                Boyz II Men        2                              [/wiki/One_Sweet_Day]                             "One Sweet Day"                /wiki/Boyz_II_Men     99       False               1985–present
# 10    1997                Boyz II Men       30                    [/wiki/4_Seasons_of_Loneliness]                   "4 Seasons of Loneliness"                /wiki/Boyz_II_Men     71       False               1985–present
# 2948  2014        5 Seconds of Summer       86         [/wiki/Amnesia_(5_Seconds_of_Summer_song)]                                   "Amnesia"        /wiki/5_Seconds_of_Summer     15       False               2011–present
# 2949  2014        5 Seconds of Summer       93                       [/wiki/She_Looks_So_Perfect]                      "She Looks So Perfect"        /wiki/5_Seconds_of_Summer      8       False               2011–present
# 2950  2014                     KONGOS       88                           [/wiki/Come_with_Me_Now]                          "Come with Me Now"              /wiki/Kongos_(band)     13       False        2007 (2007)–present
# 2951  2014          Mike WiLL Made-It       90                                  [/wiki/23_(song)]                                        "23"          /wiki/Mike_WiLL_Made-It     11  1989-03-23               2005–present
# 2952  2014  Miley Cyrus, Wiz Khalifa,       90                                  [/wiki/23_(song)]                                        "23"          /wiki/Mike_WiLL_Made-It     11  1989-03-23               2005–present
# 2953  2014                    Juicy J       90                                  [/wiki/23_(song)]                                        "23"          /wiki/Mike_WiLL_Made-It     11  1989-03-23               2005–present
# 2954  2014    Macklemore & Ryan Lewis       92                                [/wiki/White_Walls]                               "White Walls"  /wiki/Macklemore_%26_Ryan_Lewis      9       False   2008–2017 (on hiatus)[1]
# 2955  2014                     Hollis       92                                [/wiki/White_Walls]                               "White Walls"            /wiki/Hollis_(singer)      9       False               2013–present
# 2956  2014         BJ the Chicago Kid       96                              [/wiki/Studio_(song)]                                    "Studio"         /wiki/BJ_the_Chicago_Kid      5  1984-11-23               2001–present
#
# [2957 rows x 9 columns]

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %%
for index, row in largedf.iterrows():
       if row.born == False:
            largedf = largedf.drop(index)
        
largedf = largedf[pd.notnull(largedf['born'])]
largedf.isnull().sum()
# Out:
# year           0
# band_singer    0
# ranking        0
# songurl        0
# titletext      0
# url            0
# score          0
# born           0
# ya             0
# dtype: int64

# %%
#first reduce so that each artist is only in once for their best ranking
idx = largedf.groupby(['band_singer'])['ranking'].transform(min) == largedf['ranking']
rank_highest_loc = largedf[idx]
rank_highest_loc
# Out:
#       year                band_singer  ranking                                            songurl                                          titletext                          url  score        born                       ya
# 13    1992              Sir Mix-a-Lot        2                              [/wiki/Baby_Got_Back]                                    "Baby Got Back"          /wiki/Sir_Mix-a-Lot     99  1963-08-12  1983–2003, 2010–Present
# 18    1992           Vanessa Williams        4                     [/wiki/Save_the_Best_for_Last]                           "Save the Best for Last"    /wiki/Vanessa_L._Williams     97  1963-03-18             1982–present
# 32    1992               Eric Clapton        6                            [/wiki/Tears_in_Heaven]                                  "Tears in Heaven"           /wiki/Eric_Clapton     95  1945-03-30             1962–present
# 2946  2014                   Sam Hunt       76                         [/wiki/Leave_the_Night_On]                               "Leave the Night On"    /wiki/Sam_Hunt_(musician)     25  1984             2009–present           30
# 2947  2014                Naughty Boy       82                [/wiki/La_La_La_(Naughty_Boy_song)]                                         "La La La"            /wiki/Naughty_Boy     19  1985             2005–present           29
# 2951  2014          Mike WiLL Made-It       90                                  [/wiki/23_(song)]                                               "23"      /wiki/Mike_WiLL_Made-It     11  1989             2005–present           25
# 2952  2014  Miley Cyrus, Wiz Khalifa,       90                                  [/wiki/23_(song)]                                               "23"      /wiki/Mike_WiLL_Made-It     11  1989             2005–present           25
# 2956  2014         BJ the Chicago Kid       96                              [/wiki/Studio_(song)]                                           "Studio"     /wiki/BJ_the_Chicago_Kid      5  1984             2001–present           30
#
# [668 rows x 10 columns]

# %%
#now use that to plot the frequency of certain ages at the artist's highest rank
plt.hist(rank_highest_loc['age_at_song'])
# Out:
# (array([  12.,  131.,  235.,  184.,   56.,   32.,    6.,    9.,    2.,    1.]),
#  array([ 12. ,  17.8,  23.6,  29.4,  35.2,  41. ,  46.8,  52.6,  58.4,
#          64.2,  70. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %% [markdown]
# It seems that the vast majority of singers reach the top 100 when they are young, which is what I would have expected.

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %%
for index, row in largedf.iterrows():
       if row.born != False:
            largedf = largedf.drop(index)
        
largedf = largedf[pd.notnull(largedf['born'])]
largedf.isnull().sum()
# Out:
# year           0
# band_singer    0
# ranking        0
# songurl        0
# titletext      0
# url            0
# score          0
# born           0
# ya             0
# dtype: int64

# %%
banddf = largedf
banddf['ya'] = banddf['ya'].apply(lambda x: x.replace(',', ''))
banddf['ya'] = banddf['ya'].apply(lambda x: x.strip())
for index, row in banddf.iterrows():
    if len(row.ya) < 4:
        banddf = banddf.drop(index)
banddf['inception'] = banddf['ya'].apply(lambda x: int(x[:4]))
banddf
# Out:
#       year              band_singer  ranking                                            songurl                                   titletext                              url  score   born                        ya  inception
# 0     1992              Boyz II Men        1                            [/wiki/End_of_the_Road]                           "End of the Road"                /wiki/Boyz_II_Men    100  False              1985–present       1985
# 1     1992              Boyz II Men       37  [/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yester...  "It's So Hard to Say Goodbye to Yesterday"                /wiki/Boyz_II_Men     64  False              1985–present       1985
# 2     1992              Boyz II Men       84                                    [/wiki/Uhh_Ahh]                                   "Uhh Ahh"                /wiki/Boyz_II_Men     17  False              1985–present       1985
# 3     1993              Boyz II Men       12  [/wiki/In_the_Still_of_the_Night_(1956_song)#B...                  "In the Still of the Nite"                /wiki/Boyz_II_Men     89  False              1985–present       1985
# 4     1994              Boyz II Men        3                    [/wiki/I%27ll_Make_Love_to_You]                     "I'll Make Love to You"                /wiki/Boyz_II_Men     98  False              1985–present       1985
# 5     1995              Boyz II Men        5                             [/wiki/On_Bended_Knee]                            "On Bended Knee"                /wiki/Boyz_II_Men     96  False              1985–present       1985
# 2913  2014              Nico & Vinz       14                          [/wiki/Am_I_Wrong_(song)]                                "Am I Wrong"              /wiki/Nico_%26_Vinz     87  False              2010–present       2010
# 2915  2014        A Great Big World       17     [/wiki/Say_Something_(A_Great_Big_World_song)]                             "Say Something"          /wiki/A_Great_Big_World     84  False              2011–present       2011
# 2918  2014               Disclosure       28                               [/wiki/Latch_(song)]                                     "Latch"          /wiki/Disclosure_(band)     73  False  2010–present (hiatus)[1]       2010
# 2919  2014         American Authors       31                        [/wiki/Best_Day_of_My_Life]                       "Best Day of My Life"           /wiki/American_Authors     70  False              2006–present       2006
# 2922  2014            Gente de Zona       38           [/wiki/Bailando_(Enrique_Iglesias_song)]                                  "Bailando"              /wiki/Gente_de_Zona     63  False              2000–present       2000
# 2923  2014             Clean Bandit       41              [/wiki/Rather_Be_(Clean_Bandit_song)]                                 "Rather Be"               /wiki/Clean_Bandit     60  False              2008–present       2008
# 2929  2014                     MKTO       50                        [/wiki/Classic_(MKTO_song)]                                   "Classic"                       /wiki/MKTO     51  False               2010 – 2017       2010
# 2934  2014                Echosmith       59                 [/wiki/Cool_Kids_(Echosmith_song)]                                 "Cool Kids"                  /wiki/Echosmith     42  False              2009–present       2009
# 2941  2014                   Rixton       70                     [/wiki/Me_and_My_Broken_Heart]                    "Me and My Broken Heart"              /wiki/Rixton_(band)     31  False              2012–present       2012
# 2945  2014        The Neighbourhood       75                            [/wiki/Sweater_Weather]                           "Sweater Weather"          /wiki/The_Neighbourhood     26  False           2011–present[1]       2011
# 2948  2014      5 Seconds of Summer       86         [/wiki/Amnesia_(5_Seconds_of_Summer_song)]                                   "Amnesia"        /wiki/5_Seconds_of_Summer     15  False              2011–present       2011
# 2949  2014      5 Seconds of Summer       93                       [/wiki/She_Looks_So_Perfect]                      "She Looks So Perfect"        /wiki/5_Seconds_of_Summer      8  False              2011–present       2011
# 2950  2014                   KONGOS       88                           [/wiki/Come_with_Me_Now]                          "Come with Me Now"              /wiki/Kongos_(band)     13  False       2007 (2007)–present       2007
# 2954  2014  Macklemore & Ryan Lewis       92                                [/wiki/White_Walls]                               "White Walls"  /wiki/Macklemore_%26_Ryan_Lewis      9  False  2008–2017 (on hiatus)[1]       2008
# 2955  2014                   Hollis       92                                [/wiki/White_Walls]                               "White Walls"            /wiki/Hollis_(singer)      9  False              2013–present       2013
#
# [836 rows x 10 columns]

# %%
idx = banddf.groupby(['band_singer'])['ranking'].transform(min) == banddf['ranking']
best_baddf = banddf[idx]
banddf
# Out:
#       year              band_singer  ranking                                            songurl                                   titletext                              url  score   born                        ya  inception
# 0     1992              Boyz II Men        1                            [/wiki/End_of_the_Road]                           "End of the Road"                /wiki/Boyz_II_Men    100  False              1985–present       1985
# 1     1992              Boyz II Men       37  [/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yester...  "It's So Hard to Say Goodbye to Yesterday"                /wiki/Boyz_II_Men     64  False              1985–present       1985
# 2888  2013      Of Monsters and Men       65                               [/wiki/Little_Talks]                              "Little Talks"        /wiki/Of_Monsters_and_Men     36  False              2010–present       2010
# 2889  2013                    Ylvis       73         [/wiki/The_Fox_(What_Does_the_Fox_Say%3F)]          "The Fox (What Does the Fox Say?)"                      /wiki/Ylvis     28  False              2000–present       2000
# 2907  2014                   Magic!        7                                [/wiki/Rude_(song)]                                      "Rude"                     /wiki/Magic!     94  False       2012 (2012)–present       2012
# 2912  2014                 Bastille       12                    [/wiki/Pompeii_(Bastille_song)]                                   "Pompeii"            /wiki/Bastille_(band)     89  False              2010–present       2010
# 2913  2014              Nico & Vinz       14                          [/wiki/Am_I_Wrong_(song)]                                "Am I Wrong"              /wiki/Nico_%26_Vinz     87  False              2010–present       2010
# 2915  2014        A Great Big World       17     [/wiki/Say_Something_(A_Great_Big_World_song)]                             "Say Something"          /wiki/A_Great_Big_World     84  False              2011–present       2011
# 2918  2014               Disclosure       28                               [/wiki/Latch_(song)]                                     "Latch"          /wiki/Disclosure_(band)     73  False  2010–present (hiatus)[1]       2010
# 2919  2014         American Authors       31                        [/wiki/Best_Day_of_My_Life]                       "Best Day of My Life"           /wiki/American_Authors     70  False              2006–present       2006
# 2922  2014            Gente de Zona       38           [/wiki/Bailando_(Enrique_Iglesias_song)]                                  "Bailando"              /wiki/Gente_de_Zona     63  False              2000–present       2000
# 2923  2014             Clean Bandit       41              [/wiki/Rather_Be_(Clean_Bandit_song)]                                 "Rather Be"               /wiki/Clean_Bandit     60  False              2008–present       2008
# 2929  2014                     MKTO       50                        [/wiki/Classic_(MKTO_song)]                                   "Classic"                       /wiki/MKTO     51  False               2010 – 2017       2010
# 2934  2014                Echosmith       59                 [/wiki/Cool_Kids_(Echosmith_song)]                                 "Cool Kids"                  /wiki/Echosmith     42  False              2009–present       2009
# 2941  2014                   Rixton       70                     [/wiki/Me_and_My_Broken_Heart]                    "Me and My Broken Heart"              /wiki/Rixton_(band)     31  False              2012–present       2012
# 2945  2014        The Neighbourhood       75                            [/wiki/Sweater_Weather]                           "Sweater Weather"          /wiki/The_Neighbourhood     26  False           2011–present[1]       2011
# 2948  2014      5 Seconds of Summer       86         [/wiki/Amnesia_(5_Seconds_of_Summer_song)]                                   "Amnesia"        /wiki/5_Seconds_of_Summer     15  False              2011–present       2011
# 2949  2014      5 Seconds of Summer       93                       [/wiki/She_Looks_So_Perfect]                      "She Looks So Perfect"        /wiki/5_Seconds_of_Summer      8  False              2011–present       2011
# 2950  2014                   KONGOS       88                           [/wiki/Come_with_Me_Now]                          "Come with Me Now"              /wiki/Kongos_(band)     13  False       2007 (2007)–present       2007
# 2954  2014  Macklemore & Ryan Lewis       92                                [/wiki/White_Walls]                               "White Walls"  /wiki/Macklemore_%26_Ryan_Lewis      9  False  2008–2017 (on hiatus)[1]       2008
# 2955  2014                   Hollis       92                                [/wiki/White_Walls]                               "White Walls"            /wiki/Hollis_(singer)      9  False              2013–present       2013
#
# [836 rows x 10 columns]

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?
